# %%
import numpy as np
import pickle
import main
import integrators
import interactions
import visualizer
import generator
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
with open('test run 20.pkl', 'rb') as f:
    data = pickle.load(f)

#radii = main.radii_maker(initial_conditions['mass'], 1450)
#print(radii)
#print(initial_conditions)


#data = main.run(initial_conditions['positions'], initial_conditions['velocities'], initial_conditions['mass'], radii, '', 3*60*60, 1000, 1000, interactions.get_forces)

# %%
with open('test run 9.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
visualizer.display(data["Position"], True, 67)
visualizer.display_energy(data["Kinetic Energy"], data["Potential Energy"], 67)
