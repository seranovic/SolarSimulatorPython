# %%
import numpy as np
import pickle
import main
import integrators
import interactions
import visualizer
import generator

# %%
with open('initial_conditions.pkl', 'rb') as f:
    initial_conditions = pickle.load(f)

print(initial_conditions)

data = main.run(initial_conditions['positions'], initial_conditions['velocities'], initial_conditions['mass'], 67, '', 3*60*60, 100, 100, interactions.get_forces)

visualizer.display(data["Position"], True)
visualizer.display_energy(data["Kinetic Energy"], data["Potential Energy"])
