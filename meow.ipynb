# %%
import numpy as np
import pickle
import main
import integrators
import interactions
import visualizer
import generator
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
with open('initial_conditions.pkl', 'rb') as f:
    initial_conditions = pickle.load(f)

radii = main.radii_maker(initial_conditions['mass'], 1450)
#print(radii)
#print(initial_conditions)


data = main.run(initial_conditions['positions'], initial_conditions['velocities'], initial_conditions['mass'], radii, '', 3*60*60, 1000, 1000, interactions.get_forces)

visualizer.display(data["Position"], True)
visualizer.display_energy(data["Kinetic Energy"], data["Potential Energy"])
# Out:
#  -1.3800217784839194e+31 +/- 1.2047983030373944e+28

# %%
with open('positions.pkl', 'wb') as f:
    pickle.dump(data['Position'], f)
